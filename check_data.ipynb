# %%
import pickle
from PIL import Image
import time

# %%
data = pickle.load(open('./data/data1.pkl', 'rb'))

# %%
# Out:
# RAWMOUSE (size: 24) instance at 0x000002EBB8344CD0:
#   usFlags: 0
#   union: <ctypes_wrappers.MOUSE_ONION object at 0x000002EBB85714D0>
#   ulRawButtons: 0
#   lLastX: 4
#   lLastY: 4
#   ulExtraInformation: 0

# %%
print(data[1][20][1].union.structure.to_string())
# Out:
# MOUSE_FLAGS (size: 4) instance at 0x000002EBB88EC950:
#   usButtonFlags: 1024
#   usButtonData: 65416

# %%
data[1][2][1].ulButtons
# Out:
# 0

# %%
# print('3')
# time.sleep(1)
# print('2')
# time.sleep(1)
# print('1')
# time.sleep(1)
# print('Go!')

for i in range(len(data[1])):
    time.sleep(1/600)
    print(data[1][i], "                ", end="\r")
# Out:
# [(-1, -13)]                  ), (-19, -26), (-1, -29), (26, -22), (51, -6), (42, 10), (19, 22), (3, 30), (-3, 29), (0, 21), (8, 9), (31, -11), (34, -28), (27, -30), (2, -14), (-23, 2), (-55, 23), (-69, 30), (-18, 19), (14, 12), (50, 11), (26, 9), (-1, 7), (-17, 6), (-29, 0), (-18, -7), (-1, -4), (4, -6), (1, 0)]

# %%
# Out:
# [[<Key.ctrl_l: <162>>, '\x12', '\x12'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [<Key.ctrl_l: <162>>],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
# ...
